# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
import numpy as np
from matplotlib import pyplot as plt

(cifar10_x_train, cifar10_y_train), (cifar10_x_test, cifar10_y_test) = cifar10.load_data()
assert cifar10_x_train.shape == (50000, 32, 32, 3)
assert cifar10_x_test.shape == (10000, 32, 32, 3)
assert cifar10_y_train.shape == (50000, 1)
assert cifar10_y_test.shape == (10000, 1)

classes = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

cifar10_x_train = (cifar10_x_train / 255.).astype(np.float32)
cifar10_x_test = (cifar10_x_test / 255.).astype(np.float32)

# Split training data into train and validation sets
val_split = 0.2
num_val_samples = int(cifar10_x_train.shape[0] * val_split)

cifar10_x_val = cifar10_x_train[:num_val_samples]
cifar10_y_val = cifar10_y_train[:num_val_samples]

cifar10_x_train = cifar10_x_train[num_val_samples:]
cifar10_y_train = cifar10_y_train[num_val_samples:]

# Separate data into two groups for training
cond_1_train = cifar10_y_train[:, 0] < 5
cifar10_x_train_1 = cifar10_x_train[cond_1_train]
cifar10_y_train_1 = cifar10_y_train[cond_1_train]

cond_2_train = cifar10_y_train[:, 0] >= 5
cifar10_x_train_2 = cifar10_x_train[cond_2_train]
cifar10_y_train_2 = cifar10_y_train[cond_2_train]

# Separate validation data into two groups
cond_1_val = cifar10_y_val[:, 0] < 5
cifar10_x_val_1 = cifar10_x_val[cond_1_val]
cifar10_y_val_1 = cifar10_y_val[cond_1_val]

cond_2_val = cifar10_y_val[:, 0] >= 5
cifar10_x_val_2 = cifar10_x_val[cond_2_val]
cifar10_y_val_2 = cifar10_y_val[cond_2_val]

# Separate test data into two groups
cond_1_test = cifar10_y_test[:, 0] < 5
cifar10_x_test_1 = cifar10_x_test[cond_1_test]
cifar10_y_test_1 = cifar10_y_test[cond_1_test]

cond_2_test = cifar10_y_test[:, 0] >= 5
cifar10_x_test_2 = cifar10_x_test[cond_2_test]
cifar10_y_test_2 = cifar10_y_test[cond_2_test]

# %%
def datagenerator(X1, X2, Y1, Y2, batchsize):
    size1 = X1.shape[0]
    size2 = X2.shape[0]
    Y1_cat = tf.keras.utils.to_categorical(Y1, num_classes=5)
    Y2_cat = tf.keras.utils.to_categorical(Y2 - 5, num_classes=5)

    while True:
        num1 = np.random.randint(0, size1, batchsize)
        num2 = np.random.randint(0, size2, batchsize)
        x_data = (X1[num1] + X2[num2]) / 2.0
        y_data = (Y1_cat[num1], Y2_cat[num2])
        yield x_data, y_data

datagen = datagenerator(cifar10_x_train_1, cifar10_x_train_2, cifar10_y_train_1, cifar10_y_train_2, 1)
x, y = next(datagen)

print("first: {}, second = {}".format(classes[np.argmax(y[0][0])], classes[np.argmax(y[1][0]) + 5]))
#print(np.min(x[0]),np.max(x[0]))
plt.imshow(x[0])
# Out:
# first: deer, second = truck

# %%
def enhanced_cnn_model():
    inputs = tf.keras.Input(shape=(32, 32, 3))

    # First convolutional block
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    # Second convolutional block
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    # Global Average Pooling
    x = layers.GlobalAveragePooling2D()(x)

    # Fully connected layers for output 1
    fc1_output1 = layers.Dense(1024, activation='relu')(x)
    fc1_output1 = layers.Dropout(0.5)(fc1_output1)
    output1 = layers.Dense(5, activation='softmax', name='output1')(fc1_output1)

    # Fully connected layers for output 2
    fc1_output2 = layers.Dense(1024, activation='relu')(x)
    fc1_output2 = layers.Dropout(0.5)(fc1_output2)
    output2 = layers.Dense(5, activation='softmax', name='output2')(fc1_output2)

    model = Model(inputs=inputs, outputs=[output1, output2])
    return model

# %%
class LabelSmoothingLoss(tf.keras.losses.Loss):
    def __init__(self, smoothing=0.0):
        super(LabelSmoothingLoss, self).__init__()
        self.smoothing = smoothing

    def call(self, y_true, y_pred):
        num_classes = tf.cast(tf.shape(y_pred)[-1], tf.float32)
        smooth_positives = 1.0 - self.smoothing
        smooth_negatives = self.smoothing / num_classes
        y_true_smoothed = y_true * smooth_positives + smooth_negatives
        return tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_true_smoothed, y_pred))

# %%
# Define learning rate scheduler
initial_lr = 0.001
scheduler = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=initial_lr,
    decay_steps=10 * 500,  # Assuming 10 epochs
    decay_rate=0.5,
    staircase=True
)

# %%
model = enhanced_cnn_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=scheduler),
    loss={'output1': LabelSmoothingLoss(smoothing=0.1), 'output2': LabelSmoothingLoss(smoothing=0.1)},
    metrics={'output1': 'accuracy', 'output2': 'accuracy'}
)
"""
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=scheduler),
              loss={'output1': 'categorical_crossentropy', 'output2': 'categorical_crossentropy'},
              metrics={'output1': 'accuracy', 'output2': 'accuracy'})
"""

train_gen = datagenerator(cifar10_x_train_1, cifar10_x_train_2, cifar10_y_train_1, cifar10_y_train_2, 64)
val_gen = datagenerator(cifar10_x_val_1, cifar10_x_val_2, cifar10_y_val_1, cifar10_y_val_2, 64)

history = model.fit(
    train_gen,
    steps_per_epoch=500,
    epochs=50,
    validation_data=val_gen,
    validation_steps=100
)
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 25s 46ms/step - loss: 3.1564 - output1_accuracy: 0.3778 - output1_loss: 1.6151 - output2_accuracy: 0.4260 - output2_loss: 1.5413 - val_loss: 3.4434 - val_output1_accuracy: 0.2792 - val_output1_loss: 1.8531 - val_output2_accuracy: 0.4598 - val_output2_loss: 1.5903
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 2.4999 - output1_accuracy: 0.4883 - output1_loss: 1.3136 - output2_accuracy: 0.5829 - output2_loss: 1.1863 - val_loss: 2.6656 - val_output1_accuracy: 0.4511 - val_output1_loss: 1.3339 - val_output2_accuracy: 0.5116 - val_output2_loss: 1.3317
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 2.3330 - output1_accuracy: 0.5401 - output1_loss: 1.2423 - output2_accuracy: 0.6402 - output2_loss: 1.0907 - val_loss: 3.0391 - val_output1_accuracy: 0.3564 - val_output1_loss: 1.6967 - val_output2_accuracy: 0.5059 - val_output2_loss: 1.3424
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 2.2411 - output1_accuracy: 0.5691 - output1_loss: 1.1993 - output2_accuracy: 0.6738 - output2_loss: 1.0417 - val_loss: 2.6824 - val_output1_accuracy: 0.4484 - val_output1_loss: 1.4970 - val_output2_accuracy: 0.5719 - val_output2_loss: 1.1854
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 2.1873 - output1_accuracy: 0.5833 - output1_loss: 1.1782 - output2_accuracy: 0.6925 - output2_loss: 1.0090 - val_loss: 2.5395 - val_output1_accuracy: 0.4992 - val_output1_loss: 1.3129 - val_output2_accuracy: 0.5808 - val_output2_loss: 1.2266
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 2.1120 - output1_accuracy: 0.6087 - output1_loss: 1.1367 - output2_accuracy: 0.7088 - output2_loss: 0.9753 - val_loss: 2.5476 - val_output1_accuracy: 0.5609 - val_output1_loss: 1.2047 - val_output2_accuracy: 0.5220 - val_output2_loss: 1.3429
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 2.0681 - output1_accuracy: 0.6204 - output1_loss: 1.1192 - output2_accuracy: 0.7253 - output2_loss: 0.9489 - val_loss: 2.2430 - val_output1_accuracy: 0.5947 - val_output1_loss: 1.1686 - val_output2_accuracy: 0.6488 - val_output2_loss: 1.0744
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 2.0207 - output1_accuracy: 0.6389 - output1_loss: 1.0874 - output2_accuracy: 0.7351 - output2_loss: 0.9333 - val_loss: 2.3569 - val_output1_accuracy: 0.5919 - val_output1_loss: 1.1601 - val_output2_accuracy: 0.5742 - val_output2_loss: 1.1968
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.9960 - output1_accuracy: 0.6414 - output1_loss: 1.0837 - output2_accuracy: 0.7407 - output2_loss: 0.9123 - val_loss: 2.6219 - val_output1_accuracy: 0.5522 - val_output1_loss: 1.2331 - val_output2_accuracy: 0.5144 - val_output2_loss: 1.3888
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.9624 - output1_accuracy: 0.6536 - output1_loss: 1.0620 - output2_accuracy: 0.7494 - output2_loss: 0.9004 - val_loss: 2.2040 - val_output1_accuracy: 0.6016 - val_output1_loss: 1.1621 - val_output2_accuracy: 0.6803 - val_output2_loss: 1.0420
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.8838 - output1_accuracy: 0.6766 - output1_loss: 1.0246 - output2_accuracy: 0.7742 - output2_loss: 0.8592 - val_loss: 2.0602 - val_output1_accuracy: 0.6237 - val_output1_loss: 1.1045 - val_output2_accuracy: 0.7166 - val_output2_loss: 0.9556
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.8279 - output1_accuracy: 0.6920 - output1_loss: 0.9956 - output2_accuracy: 0.7890 - output2_loss: 0.8323 - val_loss: 2.3868 - val_output1_accuracy: 0.5798 - val_output1_loss: 1.2643 - val_output2_accuracy: 0.6538 - val_output2_loss: 1.1226
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.8071 - output1_accuracy: 0.6989 - output1_loss: 0.9868 - output2_accuracy: 0.7908 - output2_loss: 0.8203 - val_loss: 1.9638 - val_output1_accuracy: 0.6495 - val_output1_loss: 1.0595 - val_output2_accuracy: 0.7484 - val_output2_loss: 0.9042
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.8089 - output1_accuracy: 0.6997 - output1_loss: 0.9818 - output2_accuracy: 0.7880 - output2_loss: 0.8272 - val_loss: 2.0262 - val_output1_accuracy: 0.6509 - val_output1_loss: 1.0505 - val_output2_accuracy: 0.7036 - val_output2_loss: 0.9757
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.7811 - output1_accuracy: 0.7046 - output1_loss: 0.9693 - output2_accuracy: 0.7986 - output2_loss: 0.8118 - val_loss: 2.1636 - val_output1_accuracy: 0.6302 - val_output1_loss: 1.1186 - val_output2_accuracy: 0.6867 - val_output2_loss: 1.0450
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.7559 - output1_accuracy: 0.7113 - output1_loss: 0.9551 - output2_accuracy: 0.8042 - output2_loss: 0.8007 - val_loss: 2.1938 - val_output1_accuracy: 0.6453 - val_output1_loss: 1.0597 - val_output2_accuracy: 0.6419 - val_output2_loss: 1.1340
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.7483 - output1_accuracy: 0.7173 - output1_loss: 0.9498 - output2_accuracy: 0.8068 - output2_loss: 0.7985 - val_loss: 2.1592 - val_output1_accuracy: 0.5959 - val_output1_loss: 1.1815 - val_output2_accuracy: 0.7020 - val_output2_loss: 0.9777
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.7270 - output1_accuracy: 0.7226 - output1_loss: 0.9470 - output2_accuracy: 0.8151 - output2_loss: 0.7801 - val_loss: 1.9162 - val_output1_accuracy: 0.6617 - val_output1_loss: 1.0454 - val_output2_accuracy: 0.7659 - val_output2_loss: 0.8708
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.7082 - output1_accuracy: 0.7316 - output1_loss: 0.9314 - output2_accuracy: 0.8156 - output2_loss: 0.7767 - val_loss: 2.3289 - val_output1_accuracy: 0.6452 - val_output1_loss: 1.0847 - val_output2_accuracy: 0.6069 - val_output2_loss: 1.2442
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.7098 - output1_accuracy: 0.7301 - output1_loss: 0.9273 - output2_accuracy: 0.8112 - output2_loss: 0.7825 - val_loss: 2.0126 - val_output1_accuracy: 0.6353 - val_output1_loss: 1.0868 - val_output2_accuracy: 0.7336 - val_output2_loss: 0.9258
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 47ms/step - loss: 1.6609 - output1_accuracy: 0.7435 - output1_loss: 0.9022 - output2_accuracy: 0.8250 - output2_loss: 0.7587 - val_loss: 1.8803 - val_output1_accuracy: 0.6853 - val_output1_loss: 1.0095 - val_output2_accuracy: 0.7597 - val_output2_loss: 0.8708
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.6461 - output1_accuracy: 0.7467 - output1_loss: 0.8974 - output2_accuracy: 0.8313 - output2_loss: 0.7487 - val_loss: 1.9739 - val_output1_accuracy: 0.6644 - val_output1_loss: 1.0582 - val_output2_accuracy: 0.7387 - val_output2_loss: 0.9157
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.6171 - output1_accuracy: 0.7552 - output1_loss: 0.8810 - output2_accuracy: 0.8400 - output2_loss: 0.7361 - val_loss: 1.8702 - val_output1_accuracy: 0.6841 - val_output1_loss: 1.0021 - val_output2_accuracy: 0.7702 - val_output2_loss: 0.8681
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.6064 - output1_accuracy: 0.7582 - output1_loss: 0.8780 - output2_accuracy: 0.8421 - output2_loss: 0.7284 - val_loss: 1.8718 - val_output1_accuracy: 0.6914 - val_output1_loss: 0.9932 - val_output2_accuracy: 0.7605 - val_output2_loss: 0.8785
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5992 - output1_accuracy: 0.7629 - output1_loss: 0.8777 - output2_accuracy: 0.8463 - output2_loss: 0.7215 - val_loss: 2.0204 - val_output1_accuracy: 0.6195 - val_output1_loss: 1.1461 - val_output2_accuracy: 0.7613 - val_output2_loss: 0.8743
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5815 - output1_accuracy: 0.7658 - output1_loss: 0.8636 - output2_accuracy: 0.8456 - output2_loss: 0.7179 - val_loss: 1.8188 - val_output1_accuracy: 0.6894 - val_output1_loss: 0.9857 - val_output2_accuracy: 0.7800 - val_output2_loss: 0.8331
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5897 - output1_accuracy: 0.7606 - output1_loss: 0.8703 - output2_accuracy: 0.8459 - output2_loss: 0.7193 - val_loss: 1.8341 - val_output1_accuracy: 0.6866 - val_output1_loss: 1.0026 - val_output2_accuracy: 0.7861 - val_output2_loss: 0.8316
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5721 - output1_accuracy: 0.7643 - output1_loss: 0.8645 - output2_accuracy: 0.8519 - output2_loss: 0.7076 - val_loss: 1.8926 - val_output1_accuracy: 0.6925 - val_output1_loss: 1.0013 - val_output2_accuracy: 0.7528 - val_output2_loss: 0.8914
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5729 - output1_accuracy: 0.7693 - output1_loss: 0.8584 - output2_accuracy: 0.8501 - output2_loss: 0.7146 - val_loss: 1.8335 - val_output1_accuracy: 0.6895 - val_output1_loss: 1.0046 - val_output2_accuracy: 0.7867 - val_output2_loss: 0.8289
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5627 - output1_accuracy: 0.7693 - output1_loss: 0.8535 - output2_accuracy: 0.8507 - output2_loss: 0.7093 - val_loss: 1.9069 - val_output1_accuracy: 0.6553 - val_output1_loss: 1.0621 - val_output2_accuracy: 0.7783 - val_output2_loss: 0.8447
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5342 - output1_accuracy: 0.7781 - output1_loss: 0.8421 - output2_accuracy: 0.8626 - output2_loss: 0.6921 - val_loss: 1.8561 - val_output1_accuracy: 0.6719 - val_output1_loss: 1.0281 - val_output2_accuracy: 0.7883 - val_output2_loss: 0.8280
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5175 - output1_accuracy: 0.7846 - output1_loss: 0.8294 - output2_accuracy: 0.8645 - output2_loss: 0.6881 - val_loss: 1.7951 - val_output1_accuracy: 0.7028 - val_output1_loss: 0.9745 - val_output2_accuracy: 0.7887 - val_output2_loss: 0.8206
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5276 - output1_accuracy: 0.7806 - output1_loss: 0.8330 - output2_accuracy: 0.8598 - output2_loss: 0.6946 - val_loss: 1.8635 - val_output1_accuracy: 0.6780 - val_output1_loss: 1.0276 - val_output2_accuracy: 0.7809 - val_output2_loss: 0.8359
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5020 - output1_accuracy: 0.7879 - output1_loss: 0.8202 - output2_accuracy: 0.8685 - output2_loss: 0.6818 - val_loss: 1.9175 - val_output1_accuracy: 0.6631 - val_output1_loss: 1.0646 - val_output2_accuracy: 0.7714 - val_output2_loss: 0.8529
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.5084 - output1_accuracy: 0.7853 - output1_loss: 0.8259 - output2_accuracy: 0.8668 - output2_loss: 0.6825 - val_loss: 1.8144 - val_output1_accuracy: 0.6950 - val_output1_loss: 0.9904 - val_output2_accuracy: 0.7884 - val_output2_loss: 0.8240
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4988 - output1_accuracy: 0.7916 - output1_loss: 0.8170 - output2_accuracy: 0.8659 - output2_loss: 0.6819 - val_loss: 1.8735 - val_output1_accuracy: 0.6859 - val_output1_loss: 1.0054 - val_output2_accuracy: 0.7641 - val_output2_loss: 0.8681
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4944 - output1_accuracy: 0.7906 - output1_loss: 0.8187 - output2_accuracy: 0.8677 - output2_loss: 0.6757 - val_loss: 1.8467 - val_output1_accuracy: 0.6944 - val_output1_loss: 1.0010 - val_output2_accuracy: 0.7770 - val_output2_loss: 0.8457
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4896 - output1_accuracy: 0.7897 - output1_loss: 0.8196 - output2_accuracy: 0.8710 - output2_loss: 0.6700 - val_loss: 1.8296 - val_output1_accuracy: 0.6950 - val_output1_loss: 0.9837 - val_output2_accuracy: 0.7755 - val_output2_loss: 0.8459
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4878 - output1_accuracy: 0.7960 - output1_loss: 0.8088 - output2_accuracy: 0.8679 - output2_loss: 0.6790 - val_loss: 1.8354 - val_output1_accuracy: 0.6891 - val_output1_loss: 1.0013 - val_output2_accuracy: 0.7817 - val_output2_loss: 0.8342
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4957 - output1_accuracy: 0.7928 - output1_loss: 0.8111 - output2_accuracy: 0.8650 - output2_loss: 0.6845 - val_loss: 1.8531 - val_output1_accuracy: 0.6778 - val_output1_loss: 1.0251 - val_output2_accuracy: 0.7831 - val_output2_loss: 0.8280
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4705 - output1_accuracy: 0.7990 - output1_loss: 0.8004 - output2_accuracy: 0.8751 - output2_loss: 0.6701 - val_loss: 1.7864 - val_output1_accuracy: 0.7017 - val_output1_loss: 0.9725 - val_output2_accuracy: 0.7927 - val_output2_loss: 0.8140
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4655 - output1_accuracy: 0.7957 - output1_loss: 0.8074 - output2_accuracy: 0.8786 - output2_loss: 0.6582 - val_loss: 1.7928 - val_output1_accuracy: 0.7031 - val_output1_loss: 0.9679 - val_output2_accuracy: 0.7844 - val_output2_loss: 0.8248
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4777 - output1_accuracy: 0.7942 - output1_loss: 0.8131 - output2_accuracy: 0.8737 - output2_loss: 0.6646 - val_loss: 1.8138 - val_output1_accuracy: 0.6997 - val_output1_loss: 0.9827 - val_output2_accuracy: 0.7855 - val_output2_loss: 0.8311
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4676 - output1_accuracy: 0.8020 - output1_loss: 0.7959 - output2_accuracy: 0.8704 - output2_loss: 0.6717 - val_loss: 1.8149 - val_output1_accuracy: 0.6981 - val_output1_loss: 0.9919 - val_output2_accuracy: 0.7892 - val_output2_loss: 0.8230
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4634 - output1_accuracy: 0.7988 - output1_loss: 0.8013 - output2_accuracy: 0.8777 - output2_loss: 0.6621 - val_loss: 1.8122 - val_output1_accuracy: 0.6989 - val_output1_loss: 0.9768 - val_output2_accuracy: 0.7816 - val_output2_loss: 0.8354
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4523 - output1_accuracy: 0.8047 - output1_loss: 0.7898 - output2_accuracy: 0.8760 - output2_loss: 0.6625 - val_loss: 1.7837 - val_output1_accuracy: 0.7023 - val_output1_loss: 0.9735 - val_output2_accuracy: 0.7937 - val_output2_loss: 0.8102
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4584 - output1_accuracy: 0.8018 - output1_loss: 0.8001 - output2_accuracy: 0.8787 - output2_loss: 0.6583 - val_loss: 1.7900 - val_output1_accuracy: 0.7066 - val_output1_loss: 0.9692 - val_output2_accuracy: 0.7894 - val_output2_loss: 0.8208
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4572 - output1_accuracy: 0.8007 - output1_loss: 0.7956 - output2_accuracy: 0.8770 - output2_loss: 0.6616 - val_loss: 1.8294 - val_output1_accuracy: 0.6875 - val_output1_loss: 0.9993 - val_output2_accuracy: 0.7842 - val_output2_loss: 0.8301
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4514 - output1_accuracy: 0.8084 - output1_loss: 0.7879 - output2_accuracy: 0.8772 - output2_loss: 0.6635 - val_loss: 1.7912 - val_output1_accuracy: 0.7048 - val_output1_loss: 0.9684 - val_output2_accuracy: 0.7967 - val_output2_loss: 0.8229
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - loss: 1.4396 - output1_accuracy: 0.8102 - output1_loss: 0.7854 - output2_accuracy: 0.8805 - output2_loss: 0.6542 - val_loss: 1.8291 - val_output1_accuracy: 0.6920 - val_output1_loss: 0.9995 - val_output2_accuracy: 0.7803 - val_output2_loss: 0.8296

# %%
# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Save the model weights
model.save_weights("enhanced_cnn_best.weights.h5")

# %%
def eval_model(model):
    testgen = datagenerator(cifar10_x_test_1, cifar10_x_test_2, cifar10_y_test_1, cifar10_y_test_2, 10000)
    eval_samples_x, eval_samples_y = next(testgen)
    predictions = model.predict(eval_samples_x)
    pred1 = np.argmax(predictions[0], axis=1)
    pred2 = np.argmax(predictions[1], axis=1)
    correct_guesses_1 = pred1 == np.argmax(eval_samples_y[0], axis=1)
    correct_guesses_2 = pred2 == np.argmax(eval_samples_y[1], axis=1)
    return (np.mean(correct_guesses_1) + np.mean(correct_guesses_2)) / 2

repeat_eval = 10
eval_results = []
for i in range(repeat_eval):
    eval_results.append(eval_model(model))

print("Mean accuracy =", np.mean(eval_results))
print("Standard deviation =", np.std(eval_results))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Mean accuracy = 0.740095
# Standard deviation = 0.002740752633858087
