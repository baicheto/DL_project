# %% [markdown]
# #Separation of CIFAR-10 Images
#
# The model takes as input an image created by averaging two random samples from CIFAR-10 and is tasked with predicting the categories of the two components.
#
# The first image belongs to the first five categories (airplane, automobile, bird, cat, deer), while the second belongs to the remaining categories (dog, frog, horse, ship, truck). The model must return two labels, each within a range of five possible values.
#
# The evaluation metric for the model is as follows: calculate the classification accuracy for the two component images and then compute their average.
#
# The metric should be evaluated on 10,000 inputs generated from test data. Repeat the calculation 10 times and measure the standard deviation, which must be reported.
#
# A data generator and some examples are provided below.

# %% [markdown]
# #Data preparation

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
import numpy as np
from matplotlib import pyplot as plt

# %%
(cifar10_x_train, cifar10_y_train), (cifar10_x_test, cifar10_y_test) = cifar10.load_data()
assert cifar10_x_train.shape == (50000, 32, 32, 3)
assert cifar10_x_test.shape == (10000, 32, 32, 3)
assert cifar10_y_train.shape == (50000, 1)
assert cifar10_y_test.shape == (10000, 1)

classes = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

cifar10_x_train = (cifar10_x_train/255.).astype(np.float32)
cifar10_x_test = (cifar10_x_test/255.).astype(np.float32)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# Let us split the images in two groups, according to their label.

# %%
# Split training data into train and validation sets
val_split = 0.1
num_val_samples = int(cifar10_x_train.shape[0] * val_split)

cifar10_x_val = cifar10_x_train[:num_val_samples]
cifar10_y_val = cifar10_y_train[:num_val_samples]

cifar10_x_train = cifar10_x_train[num_val_samples:]
cifar10_y_train = cifar10_y_train[num_val_samples:]

# Separate data into two groups for training
cond_1_train = cifar10_y_train[:, 0] < 5
cifar10_x_train_1 = cifar10_x_train[cond_1_train]
cifar10_y_train_1 = cifar10_y_train[cond_1_train]

cond_2_train = cifar10_y_train[:, 0] >= 5
cifar10_x_train_2 = cifar10_x_train[cond_2_train]
cifar10_y_train_2 = cifar10_y_train[cond_2_train]

# Separate validation data into two groups
cond_1_val = cifar10_y_val[:, 0] < 5
cifar10_x_val_1 = cifar10_x_val[cond_1_val]
cifar10_y_val_1 = cifar10_y_val[cond_1_val]

cond_2_val = cifar10_y_val[:, 0] >= 5
cifar10_x_val_2 = cifar10_x_val[cond_2_val]
cifar10_y_val_2 = cifar10_y_val[cond_2_val]

# Separate test data into two groups
cond_1_test = cifar10_y_test[:, 0] < 5
cifar10_x_test_1 = cifar10_x_test[cond_1_test]
cifar10_y_test_1 = cifar10_y_test[cond_1_test]

cond_2_test = cifar10_y_test[:, 0] >= 5
cifar10_x_test_2 = cifar10_x_test[cond_2_test]
cifar10_y_test_2 = cifar10_y_test[cond_2_test]

# %% [markdown]
# Now we can define the generator. The input consists of two datasets (X1,X2), their corresponding labels (Y1,Y2), and a batch size.
#
# The generator returns (x_data,y_data), where:
# * x_data is a batch of images obtained by averaging random samples from X1 and X2.
# * y_data is a pair of batches of labels corresponding to the component images, expressed in categorical format.

# %%
def datagenerator(X1,X2,Y1,Y2,batchsize):
  size1 = X1.shape[0]
  size2 = X2.shape[0]
  Y1_cat = tf.keras.utils.to_categorical(Y1, num_classes=5)
  Y2_cat = tf.keras.utils.to_categorical(Y2-5, num_classes=5)

  while True:
    num1 = np.random.randint(0, size1, batchsize)
    num2 = np.random.randint(0, size2, batchsize)
    x_data = (X1[num1] + X2[num2]) / 2.0
    y_data = (Y1_cat[num1],Y2_cat[num2])

    yield x_data, y_data

# %% [markdown]
# Let us instantiate a generator on Cifar10 with batchsize=1, and let's see its behaviour.

# %%
datagen = datagenerator(cifar10_x_train_1,cifar10_x_train_2,cifar10_y_train_1,cifar10_y_train_2,1)

# %% [markdown]
# Let's generate an example, display the image that the model will take as input, and print the categories of the two overlapping components.
#
# You can re-run the cell to display new examples.

# %%
x, y = next(datagen)

print("first: {}, second = {}".format(classes[np.argmax(y[0][0])],classes[np.argmax(y[1][0])+5]))
#print(np.min(x[0]),np.max(x[0]))
plt.imshow(x[0])
# Out:
# first: automobile, second = frog

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Let us define first of all the test generator.

# %%
testgen = datagenerator(cifar10_x_test_1,cifar10_x_test_2,cifar10_y_test_1,cifar10_y_test_2,10000)

eval_samples_x, eval_samples_y = next(testgen)
print(eval_samples_x.shape)
# Out:
# (10000, 32, 32, 3)

# %% [markdown]
# We now test a model producing random guesses. You will need to replace it with your own predictive model.

# %%
def random_model(x):
  #the random model ingnore the input x and return a pair of random classes
  return(np.random.randint(0,5,(10000,2)))

# %%
def eval_model(model):
  eval_samples_x, eval_samples_y = next(testgen)
  random_guesses = model(eval_samples_x)
  correct_guesses_1 = random_guesses[:,0] == np.argmax(eval_samples_y[0],axis=1)
  correct_guesses_2 = random_guesses[:,1] == np.argmax(eval_samples_y[1],axis=1)
  return (np.mean(correct_guesses_1) + np.mean(correct_guesses_2))/2

# %%
eval_model(random_model)
# Out:
# 0.19840000000000002

# %% [markdown]
# As expected, the accuracy is around 1/5 = 0.2
#
# Let us repeat the evaluation ten times, and compute the standard deviation

# %%
repeat_eval = 10
eval_results = []
for i in range(repeat_eval):
  eval_results.append(eval_model(random_model))
print("mean accuracy = ", np.mean(eval_results))
print("standard deviation = ", np.std(eval_results))
# Out:
# mean accuracy =  0.20007000000000003
# standard deviation =  0.0038032354647063327

# %% [markdown]
# ### **Summary of the model:** CNN

# %% [markdown]
# This is the most successful model, a Convolutional Neural Network, that was created in order to solve the task given.
# The architecture consists of:
# 1. **Input layer**
# - Shape: (32, 32, 3), which is suitable for small image datasets like CIFAR-10
# 2. **Resize layer**
# - This is a preprocessing step that adjusts the input data dimensions. However, a try of resizing to 224 proved to be not performing well, so the initial dimensions of 32 were kept at the end.
# 3. **Convolutional Blocks**
# - There are 5 sequential convolutional blocks with:
# - A Conv2D layer with an increasing number of filters: 64 -> 128 -> 256 -> 512 -> 1024
# - A kernel size of (3,3) and a padding = 'same' preserve the spatial dimensions
# - Batch normalization to stabilize and normalize feature distributions
# - Swish activation for non-linearity
# - A MaxPooling2D layer with (1,1) strides, which does not reduce spatial dimensions
# - These blocks allow to progressively extract higher-level features
# 4. **Global Average Pooling**
# - A GlobalAveragePooling2D layer reduces the spatial dimensions of the feature maps to a 1D vector ((None, 1024)), summarizing spatial information
# 5. **Fully Connected Layers**
# - Two parallel branches for output1 and output2:
# - A dense layer with 1024 units and no activation, followed by a LeakyReLU activation (alpha=0.1) for non-linearity
# - Dropout (0.2) was added for regularization to prevent overfitting
# - A final dense layer with 5 units and a softmax activation for classification
# 6. **Outputs**
# - output1 and output2: Two separate predictions, each targeting 5 classes

# %%
# Resize CIFAR-10 images
# resize_layer = layers.Lambda(lambda x: tf.image.resize(x, (224, 224)))
resize_layer = layers.Lambda(lambda x: tf.image.resize(x, (32, 32)))

# %%
def enhanced_cnn_model():
    inputs = tf.keras.Input(shape=(32, 32, 3))
    x = resize_layer(inputs)

    # First convolutional block
    x = layers.Conv2D(64, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = tf.keras.activations.swish(x)
    x = layers.MaxPooling2D((1, 1))(x)

    # Second convolutional block
    x = layers.Conv2D(128, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = tf.keras.activations.swish(x)
    x = layers.MaxPooling2D((1, 1))(x)

    # Third convolutional block
    x = layers.Conv2D(256, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = tf.keras.activations.swish(x)
    x = layers.MaxPooling2D((1, 1))(x)

    # Fourth convolutional block
    x = layers.Conv2D(512, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = tf.keras.activations.swish(x)
    x = layers.MaxPooling2D((1, 1))(x)

    # Fifth convolutional block
    x = layers.Conv2D(1024, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = tf.keras.activations.swish(x)
    x = layers.MaxPooling2D((1, 1))(x)

    # Global Average Pooling
    x = layers.GlobalAveragePooling2D()(x)

    # Fully connected layers for output 1
    fc1_output1 = layers.Dense(1024, activation=None)(x)
    fc1_output1 = layers.LeakyReLU(alpha=0.1)(fc1_output1)
    fc1_output1 = layers.Dropout(0.2)(fc1_output1)
    output1 = layers.Dense(5, activation='softmax', name='output1')(fc1_output1)

    # Fully connected layers for output 2
    fc1_output2 = layers.Dense(1024, activation=None)(x)
    fc1_output2 = layers.LeakyReLU(alpha=0.1)(fc1_output2)
    fc1_output2 = layers.Dropout(0.2)(fc1_output2)
    output2 = layers.Dense(5, activation='softmax', name='output2')(fc1_output2)

    model = Model(inputs=inputs, outputs=[output1, output2])
    return model

# %% [markdown]
# **Label Smoothing Loss**
# - The implementation of Label Smoothing Loss introduces smoothing to the target labels, aiming to reduce overconfidence in predictions and improve generalization.
# - It was implemented as a subclass of tf.keras.losses.Loss

# %%
class LabelSmoothingLoss(tf.keras.losses.Loss):
    def __init__(self, smoothing=0.0):
        super(LabelSmoothingLoss, self).__init__()
        self.smoothing = smoothing

    def call(self, y_true, y_pred):
        num_classes = tf.cast(tf.shape(y_pred)[-1], tf.float32)
        smooth_positives = 1.0 - self.smoothing
        smooth_negatives = self.smoothing / num_classes
        y_true_smoothed = y_true * smooth_positives + smooth_negatives
        return tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_true_smoothed, y_pred))

# %% [markdown]
# **Learning Rate Scheduler**
# - The learning rate scheduler that was used implements an Exponential Decay strategy, where the learning rate decreases exponentially over time
# - Initial Learning Rate starts at: 0.001
# - Decay Steps: The learning rate is updated every 5*500 = 2500 steps
# - Decay Rate: After every 2500 steps, the lr is multiplied by 0.8, reducing it by 20%
# - Staircase Decay: the staircase=True setting ensures that the lr decreases in descrete steps rather than continuously
# - This learning rate scheduler strategy gradually reduces the learning rate as training progresses, allowing the model to make large updates in the early stages and smaller, more fine-tuned updates later. It helps improve convergence and reduces the risk of overshooting the optimal solution.

# %%
# Define learning rate scheduler
initial_lr = 0.001
scheduler = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=initial_lr,
    decay_steps= 5 * 500,
    decay_rate=0.8,
    staircase=True
)

# %% [markdown]
# **Optimizer with layer-specific learning rate**
# This is a custom implementation of the Adam optimizer which allows each layer in the model to have a distinct learning rate, providing fine-grained control over the training process.
# 1. Custom Adam Optimizer
# - Inherits from: tf.keras.optimizers.Adam
# - Accepts a dictionary lr_multipliers, mapping specific layers to their specific learning rate multipliers
# - Overrides the _resource_apply_dense method to scale the learning rate for each layer by its specified multiplier
# 2. Layer-Specific Learning Rate Multipliers
# - lr_multipliers assigns lower learning rates to early layers(1e-5), moderate rates to middle layers(1e-4), and higher rates to late layers and dense layers (1e-3).If we apply lower LR for the lower layers, we can preserve the general features. If we apply higher LR for the higher layers, we can help the model fine-tune more aggressively and adapt to the specifics
# - Inspiration about this method was taken from this blog: https://kharshit.github.io/blog/2019/03/22/layer-specific-learning-rates
#
# 3. Integration with Learning Rate Scheduler:
# - The learning_rate parameter uses the ExponentialDecay scheduler, ensuring the base learning rate decreases over time while still respecting the layer-specific multipliers.

# %%
# Define the optimizer with layer-specific learning rates
class CustomAdam(tf.keras.optimizers.Adam):
    def __init__(self, lr_multipliers, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.lr_multipliers = lr_multipliers

    def _resource_apply_dense(self, grad, var, apply_state=None):
        multiplier = self.lr_multipliers.get(var.name, 1.0)
        scaled_lr = self._get_hyper("learning_rate") * multiplier
        self._set_hyper("learning_rate", scaled_lr)
        return super()._resource_apply_dense(grad, var, apply_state)

lr_multipliers = {
    'conv2d/kernel:0': 1e-5,    # Early layers
    'conv2d_1/kernel:0': 1e-5,  # Early layers
    'conv2d_2/kernel:0': 1e-4,  # Middle layers
    'conv2d_3/kernel:0': 1e-4,  # Middle layers
    'conv2d_4/kernel:0': 1e-3,  # Late layers
    'conv2d_5/kernel:0': 1e-3,  # Late layers
    'dense/kernel:0': 1e-3,     # Final dense layers
    'dense_1/kernel:0': 1e-3
}

# Compile the model with a custom optimizer
custom_optimizer = CustomAdam(
    learning_rate=scheduler,
    lr_multipliers=lr_multipliers
)

# %% [markdown]
# **Train the model**
# 1. Model Definition
# - enhanced_cnn_model() is compiled with the custom optimizer defined before that incorporates layer-specific learning-rate multipliers and an exponenitial decay scheduler
# - Loss: LabelSmoothingLoss with a smoothing factor of 0.1 was applied independently to the two outputs
# - Metrics: Accuracy was used to evaluate the performance of each output
# 2. Data Generators
# - train_gen and val_gen were used to dynamically generate training and validation batches of size 64
# 3. Model Training
# - model.fit() trains the model for 120 epochs, using 500 steps per epoch for training and 100 steps per epoch for validation
# - This trainig process evaluates the model on the validation set after each epoch to monitor its performance

# %%
model = enhanced_cnn_model()
model.compile(
    optimizer=custom_optimizer,
    loss={'output1': LabelSmoothingLoss(smoothing=0.1), 'output2': LabelSmoothingLoss(smoothing=0.1)},
    metrics={'output1': 'accuracy', 'output2': 'accuracy'}
)

train_gen = datagenerator(cifar10_x_train_1, cifar10_x_train_2, cifar10_y_train_1, cifar10_y_train_2, 64)
val_gen = datagenerator(cifar10_x_val_1, cifar10_x_val_2, cifar10_y_val_1, cifar10_y_val_2, 64)

history = model.fit(
    train_gen,
    steps_per_epoch=500,
    epochs=120,
    validation_data=val_gen,
    validation_steps=100
)
# Out:
# Epoch 1/120
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - loss: 2.9988 - output1_accuracy: 0.3642 - output1_loss: 1.5181 - output2_accuracy: 0.3854 - output2_loss: 1.4807 - val_loss: 3.5619 - val_output1_accuracy: 0.2700 - val_output1_loss: 1.8005 - val_output2_accuracy: 0.2975 - val_output2_loss: 1.7614
# Epoch 2/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.6600 - output1_accuracy: 0.4434 - output1_loss: 1.3801 - output2_accuracy: 0.5185 - output2_loss: 1.2799 - val_loss: 3.0147 - val_output1_accuracy: 0.2961 - val_output1_loss: 1.8222 - val_output2_accuracy: 0.5723 - val_output2_loss: 1.1926
# Epoch 3/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.5106 - output1_accuracy: 0.4836 - output1_loss: 1.3280 - output2_accuracy: 0.5823 - output2_loss: 1.1826 - val_loss: 3.2080 - val_output1_accuracy: 0.4334 - val_output1_loss: 1.4675 - val_output2_accuracy: 0.4022 - val_output2_loss: 1.7404
# Epoch 4/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.4113 - output1_accuracy: 0.5025 - output1_loss: 1.2933 - output2_accuracy: 0.6235 - output2_loss: 1.1180 - val_loss: 2.6074 - val_output1_accuracy: 0.4539 - val_output1_loss: 1.3772 - val_output2_accuracy: 0.5742 - val_output2_loss: 1.2302
# Epoch 5/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.3469 - output1_accuracy: 0.5241 - output1_loss: 1.2686 - output2_accuracy: 0.6473 - output2_loss: 1.0783 - val_loss: 2.6234 - val_output1_accuracy: 0.4786 - val_output1_loss: 1.3583 - val_output2_accuracy: 0.5878 - val_output2_loss: 1.2650
# Epoch 6/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.2707 - output1_accuracy: 0.5454 - output1_loss: 1.2331 - output2_accuracy: 0.6647 - output2_loss: 1.0376 - val_loss: 2.4683 - val_output1_accuracy: 0.5247 - val_output1_loss: 1.2804 - val_output2_accuracy: 0.5952 - val_output2_loss: 1.1878
# Epoch 7/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.2160 - output1_accuracy: 0.5668 - output1_loss: 1.1986 - output2_accuracy: 0.6803 - output2_loss: 1.0174 - val_loss: 2.7558 - val_output1_accuracy: 0.4638 - val_output1_loss: 1.4086 - val_output2_accuracy: 0.5483 - val_output2_loss: 1.3472
# Epoch 8/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - loss: 2.1863 - output1_accuracy: 0.5707 - output1_loss: 1.1881 - output2_accuracy: 0.6925 - output2_loss: 0.9982 - val_loss: 2.5885 - val_output1_accuracy: 0.4698 - val_output1_loss: 1.4122 - val_output2_accuracy: 0.5905 - val_output2_loss: 1.1762
# Epoch 9/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.1354 - output1_accuracy: 0.5838 - output1_loss: 1.1686 - output2_accuracy: 0.7091 - output2_loss: 0.9669 - val_loss: 2.2909 - val_output1_accuracy: 0.5233 - val_output1_loss: 1.2606 - val_output2_accuracy: 0.6706 - val_output2_loss: 1.0303
# Epoch 10/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.1026 - output1_accuracy: 0.5968 - output1_loss: 1.1465 - output2_accuracy: 0.7103 - output2_loss: 0.9561 - val_loss: 2.3670 - val_output1_accuracy: 0.5408 - val_output1_loss: 1.2430 - val_output2_accuracy: 0.6314 - val_output2_loss: 1.1240
# Epoch 11/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.0648 - output1_accuracy: 0.6097 - output1_loss: 1.1274 - output2_accuracy: 0.7240 - output2_loss: 0.9374 - val_loss: 2.4240 - val_output1_accuracy: 0.5095 - val_output1_loss: 1.3623 - val_output2_accuracy: 0.6492 - val_output2_loss: 1.0617
# Epoch 12/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.0254 - output1_accuracy: 0.6223 - output1_loss: 1.1073 - output2_accuracy: 0.7303 - output2_loss: 0.9181 - val_loss: 2.1328 - val_output1_accuracy: 0.5650 - val_output1_loss: 1.2021 - val_output2_accuracy: 0.7273 - val_output2_loss: 0.9307
# Epoch 13/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 2.0010 - output1_accuracy: 0.6322 - output1_loss: 1.0945 - output2_accuracy: 0.7448 - output2_loss: 0.9065 - val_loss: 2.1359 - val_output1_accuracy: 0.6017 - val_output1_loss: 1.1429 - val_output2_accuracy: 0.7008 - val_output2_loss: 0.9930
# Epoch 14/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.9817 - output1_accuracy: 0.6302 - output1_loss: 1.0920 - output2_accuracy: 0.7504 - output2_loss: 0.8897 - val_loss: 2.0531 - val_output1_accuracy: 0.6180 - val_output1_loss: 1.1172 - val_output2_accuracy: 0.7236 - val_output2_loss: 0.9359
# Epoch 15/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.9514 - output1_accuracy: 0.6540 - output1_loss: 1.0650 - output2_accuracy: 0.7513 - output2_loss: 0.8864 - val_loss: 2.1683 - val_output1_accuracy: 0.5820 - val_output1_loss: 1.2089 - val_output2_accuracy: 0.7136 - val_output2_loss: 0.9594
# Epoch 16/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.9193 - output1_accuracy: 0.6523 - output1_loss: 1.0517 - output2_accuracy: 0.7650 - output2_loss: 0.8676 - val_loss: 2.1610 - val_output1_accuracy: 0.5697 - val_output1_loss: 1.1982 - val_output2_accuracy: 0.7131 - val_output2_loss: 0.9628
# Epoch 17/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.9044 - output1_accuracy: 0.6616 - output1_loss: 1.0395 - output2_accuracy: 0.7655 - output2_loss: 0.8648 - val_loss: 2.0466 - val_output1_accuracy: 0.5983 - val_output1_loss: 1.1330 - val_output2_accuracy: 0.7342 - val_output2_loss: 0.9136
# Epoch 18/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.8694 - output1_accuracy: 0.6723 - output1_loss: 1.0267 - output2_accuracy: 0.7769 - output2_loss: 0.8427 - val_loss: 2.0154 - val_output1_accuracy: 0.6397 - val_output1_loss: 1.0787 - val_output2_accuracy: 0.7206 - val_output2_loss: 0.9367
# Epoch 19/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.8602 - output1_accuracy: 0.6722 - output1_loss: 1.0212 - output2_accuracy: 0.7830 - output2_loss: 0.8390 - val_loss: 2.0017 - val_output1_accuracy: 0.6030 - val_output1_loss: 1.1244 - val_output2_accuracy: 0.7589 - val_output2_loss: 0.8773
# Epoch 20/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.8359 - output1_accuracy: 0.6840 - output1_loss: 1.0044 - output2_accuracy: 0.7848 - output2_loss: 0.8315 - val_loss: 1.9567 - val_output1_accuracy: 0.6377 - val_output1_loss: 1.0833 - val_output2_accuracy: 0.7589 - val_output2_loss: 0.8734
# Epoch 21/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.8117 - output1_accuracy: 0.6871 - output1_loss: 1.0007 - output2_accuracy: 0.7925 - output2_loss: 0.8110 - val_loss: 1.9162 - val_output1_accuracy: 0.6642 - val_output1_loss: 1.0378 - val_output2_accuracy: 0.7606 - val_output2_loss: 0.8784
# Epoch 22/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.8039 - output1_accuracy: 0.6925 - output1_loss: 0.9847 - output2_accuracy: 0.7887 - output2_loss: 0.8192 - val_loss: 1.9959 - val_output1_accuracy: 0.6477 - val_output1_loss: 1.0905 - val_output2_accuracy: 0.7439 - val_output2_loss: 0.9054
# Epoch 23/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.7958 - output1_accuracy: 0.6914 - output1_loss: 0.9868 - output2_accuracy: 0.7948 - output2_loss: 0.8091 - val_loss: 1.9117 - val_output1_accuracy: 0.6564 - val_output1_loss: 1.0466 - val_output2_accuracy: 0.7664 - val_output2_loss: 0.8651
# Epoch 24/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.7782 - output1_accuracy: 0.6997 - output1_loss: 0.9767 - output2_accuracy: 0.8009 - output2_loss: 0.8015 - val_loss: 1.8481 - val_output1_accuracy: 0.6750 - val_output1_loss: 1.0121 - val_output2_accuracy: 0.7786 - val_output2_loss: 0.8360
# Epoch 25/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.7617 - output1_accuracy: 0.7067 - output1_loss: 0.9666 - output2_accuracy: 0.8003 - output2_loss: 0.7951 - val_loss: 1.8767 - val_output1_accuracy: 0.6680 - val_output1_loss: 1.0322 - val_output2_accuracy: 0.7716 - val_output2_loss: 0.8445
# Epoch 26/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.7461 - output1_accuracy: 0.7070 - output1_loss: 0.9614 - output2_accuracy: 0.8071 - output2_loss: 0.7846 - val_loss: 1.8334 - val_output1_accuracy: 0.6748 - val_output1_loss: 1.0125 - val_output2_accuracy: 0.7844 - val_output2_loss: 0.8209
# Epoch 27/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.7391 - output1_accuracy: 0.7074 - output1_loss: 0.9567 - output2_accuracy: 0.8077 - output2_loss: 0.7824 - val_loss: 1.8594 - val_output1_accuracy: 0.6739 - val_output1_loss: 1.0182 - val_output2_accuracy: 0.7777 - val_output2_loss: 0.8412
# Epoch 28/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.7264 - output1_accuracy: 0.7142 - output1_loss: 0.9463 - output2_accuracy: 0.8097 - output2_loss: 0.7802 - val_loss: 1.8096 - val_output1_accuracy: 0.6875 - val_output1_loss: 1.0077 - val_output2_accuracy: 0.7989 - val_output2_loss: 0.8019
# Epoch 29/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.7164 - output1_accuracy: 0.7189 - output1_loss: 0.9399 - output2_accuracy: 0.8106 - output2_loss: 0.7765 - val_loss: 1.8604 - val_output1_accuracy: 0.6769 - val_output1_loss: 1.0185 - val_output2_accuracy: 0.7731 - val_output2_loss: 0.8419
# Epoch 30/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.7114 - output1_accuracy: 0.7227 - output1_loss: 0.9352 - output2_accuracy: 0.8143 - output2_loss: 0.7762 - val_loss: 1.8437 - val_output1_accuracy: 0.6673 - val_output1_loss: 1.0222 - val_output2_accuracy: 0.7837 - val_output2_loss: 0.8215
# Epoch 31/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.6909 - output1_accuracy: 0.7233 - output1_loss: 0.9259 - output2_accuracy: 0.8172 - output2_loss: 0.7650 - val_loss: 1.8658 - val_output1_accuracy: 0.6469 - val_output1_loss: 1.0653 - val_output2_accuracy: 0.7994 - val_output2_loss: 0.8005
# Epoch 32/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.6694 - output1_accuracy: 0.7384 - output1_loss: 0.9120 - output2_accuracy: 0.8238 - output2_loss: 0.7574 - val_loss: 1.7962 - val_output1_accuracy: 0.6892 - val_output1_loss: 0.9941 - val_output2_accuracy: 0.7967 - val_output2_loss: 0.8021
# Epoch 33/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.6677 - output1_accuracy: 0.7322 - output1_loss: 0.9169 - output2_accuracy: 0.8256 - output2_loss: 0.7509 - val_loss: 1.7602 - val_output1_accuracy: 0.7005 - val_output1_loss: 0.9642 - val_output2_accuracy: 0.7966 - val_output2_loss: 0.7960
# Epoch 34/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - loss: 1.6528 - output1_accuracy: 0.7363 - output1_loss: 0.9104 - output2_accuracy: 0.8329 - output2_loss: 0.7424 - val_loss: 1.7475 - val_output1_accuracy: 0.7056 - val_output1_loss: 0.9601 - val_output2_accuracy: 0.8045 - val_output2_loss: 0.7874
# Epoch 35/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - loss: 1.6687 - output1_accuracy: 0.7379 - output1_loss: 0.9134 - output2_accuracy: 0.8231 - output2_loss: 0.7554 - val_loss: 1.8374 - val_output1_accuracy: 0.6737 - val_output1_loss: 1.0173 - val_output2_accuracy: 0.7895 - val_output2_loss: 0.8201
# Epoch 36/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - loss: 1.6445 - output1_accuracy: 0.7385 - output1_loss: 0.9030 - output2_accuracy: 0.8289 - output2_loss: 0.7415 - val_loss: 1.7354 - val_output1_accuracy: 0.7100 - val_output1_loss: 0.9611 - val_output2_accuracy: 0.8108 - val_output2_loss: 0.7743
# Epoch 37/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - loss: 1.6259 - output1_accuracy: 0.7517 - output1_loss: 0.8827 - output2_accuracy: 0.8301 - output2_loss: 0.7432 - val_loss: 1.7353 - val_output1_accuracy: 0.7188 - val_output1_loss: 0.9458 - val_output2_accuracy: 0.8075 - val_output2_loss: 0.7895
# Epoch 38/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.6193 - output1_accuracy: 0.7527 - output1_loss: 0.8859 - output2_accuracy: 0.8372 - output2_loss: 0.7334 - val_loss: 1.8943 - val_output1_accuracy: 0.6536 - val_output1_loss: 1.0752 - val_output2_accuracy: 0.7873 - val_output2_loss: 0.8191
# Epoch 39/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.6284 - output1_accuracy: 0.7472 - output1_loss: 0.8959 - output2_accuracy: 0.8378 - output2_loss: 0.7325 - val_loss: 1.7079 - val_output1_accuracy: 0.7217 - val_output1_loss: 0.9441 - val_output2_accuracy: 0.8163 - val_output2_loss: 0.7637
# Epoch 40/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.6130 - output1_accuracy: 0.7506 - output1_loss: 0.8845 - output2_accuracy: 0.8377 - output2_loss: 0.7285 - val_loss: 1.7082 - val_output1_accuracy: 0.7284 - val_output1_loss: 0.9289 - val_output2_accuracy: 0.8092 - val_output2_loss: 0.7793
# Epoch 41/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.6086 - output1_accuracy: 0.7604 - output1_loss: 0.8787 - output2_accuracy: 0.8340 - output2_loss: 0.7299 - val_loss: 1.7107 - val_output1_accuracy: 0.7322 - val_output1_loss: 0.9232 - val_output2_accuracy: 0.8042 - val_output2_loss: 0.7875
# Epoch 42/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.6044 - output1_accuracy: 0.7536 - output1_loss: 0.8810 - output2_accuracy: 0.8387 - output2_loss: 0.7234 - val_loss: 1.7149 - val_output1_accuracy: 0.7202 - val_output1_loss: 0.9391 - val_output2_accuracy: 0.8061 - val_output2_loss: 0.7758
# Epoch 43/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5867 - output1_accuracy: 0.7626 - output1_loss: 0.8643 - output2_accuracy: 0.8433 - output2_loss: 0.7225 - val_loss: 1.7114 - val_output1_accuracy: 0.7181 - val_output1_loss: 0.9446 - val_output2_accuracy: 0.8175 - val_output2_loss: 0.7668
# Epoch 44/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5892 - output1_accuracy: 0.7656 - output1_loss: 0.8637 - output2_accuracy: 0.8395 - output2_loss: 0.7255 - val_loss: 1.6588 - val_output1_accuracy: 0.7333 - val_output1_loss: 0.9143 - val_output2_accuracy: 0.8302 - val_output2_loss: 0.7445
# Epoch 45/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - loss: 1.5792 - output1_accuracy: 0.7602 - output1_loss: 0.8680 - output2_accuracy: 0.8430 - output2_loss: 0.7112 - val_loss: 1.6867 - val_output1_accuracy: 0.7222 - val_output1_loss: 0.9392 - val_output2_accuracy: 0.8247 - val_output2_loss: 0.7475
# Epoch 46/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - loss: 1.5762 - output1_accuracy: 0.7646 - output1_loss: 0.8643 - output2_accuracy: 0.8439 - output2_loss: 0.7119 - val_loss: 1.6773 - val_output1_accuracy: 0.7389 - val_output1_loss: 0.9153 - val_output2_accuracy: 0.8194 - val_output2_loss: 0.7620
# Epoch 47/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5710 - output1_accuracy: 0.7727 - output1_loss: 0.8555 - output2_accuracy: 0.8461 - output2_loss: 0.7155 - val_loss: 1.6595 - val_output1_accuracy: 0.7320 - val_output1_loss: 0.9116 - val_output2_accuracy: 0.8214 - val_output2_loss: 0.7479
# Epoch 48/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5652 - output1_accuracy: 0.7675 - output1_loss: 0.8552 - output2_accuracy: 0.8463 - output2_loss: 0.7100 - val_loss: 1.6853 - val_output1_accuracy: 0.7277 - val_output1_loss: 0.9235 - val_output2_accuracy: 0.8184 - val_output2_loss: 0.7618
# Epoch 49/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5523 - output1_accuracy: 0.7710 - output1_loss: 0.8501 - output2_accuracy: 0.8542 - output2_loss: 0.7022 - val_loss: 1.6834 - val_output1_accuracy: 0.7175 - val_output1_loss: 0.9265 - val_output2_accuracy: 0.8222 - val_output2_loss: 0.7570
# Epoch 50/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5518 - output1_accuracy: 0.7680 - output1_loss: 0.8500 - output2_accuracy: 0.8547 - output2_loss: 0.7017 - val_loss: 1.6863 - val_output1_accuracy: 0.7275 - val_output1_loss: 0.9238 - val_output2_accuracy: 0.8192 - val_output2_loss: 0.7625
# Epoch 51/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5533 - output1_accuracy: 0.7656 - output1_loss: 0.8559 - output2_accuracy: 0.8530 - output2_loss: 0.6975 - val_loss: 1.6228 - val_output1_accuracy: 0.7459 - val_output1_loss: 0.8918 - val_output2_accuracy: 0.8339 - val_output2_loss: 0.7310
# Epoch 52/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5370 - output1_accuracy: 0.7732 - output1_loss: 0.8429 - output2_accuracy: 0.8585 - output2_loss: 0.6941 - val_loss: 1.6430 - val_output1_accuracy: 0.7398 - val_output1_loss: 0.9074 - val_output2_accuracy: 0.8306 - val_output2_loss: 0.7356
# Epoch 53/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5386 - output1_accuracy: 0.7759 - output1_loss: 0.8422 - output2_accuracy: 0.8560 - output2_loss: 0.6964 - val_loss: 1.6556 - val_output1_accuracy: 0.7314 - val_output1_loss: 0.9206 - val_output2_accuracy: 0.8352 - val_output2_loss: 0.7350
# Epoch 54/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5284 - output1_accuracy: 0.7832 - output1_loss: 0.8360 - output2_accuracy: 0.8571 - output2_loss: 0.6924 - val_loss: 1.6283 - val_output1_accuracy: 0.7416 - val_output1_loss: 0.8964 - val_output2_accuracy: 0.8339 - val_output2_loss: 0.7320
# Epoch 55/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5318 - output1_accuracy: 0.7767 - output1_loss: 0.8380 - output2_accuracy: 0.8558 - output2_loss: 0.6938 - val_loss: 1.6343 - val_output1_accuracy: 0.7391 - val_output1_loss: 0.9051 - val_output2_accuracy: 0.8364 - val_output2_loss: 0.7291
# Epoch 56/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5271 - output1_accuracy: 0.7786 - output1_loss: 0.8342 - output2_accuracy: 0.8571 - output2_loss: 0.6929 - val_loss: 1.6346 - val_output1_accuracy: 0.7459 - val_output1_loss: 0.8946 - val_output2_accuracy: 0.8272 - val_output2_loss: 0.7400
# Epoch 57/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5130 - output1_accuracy: 0.7836 - output1_loss: 0.8303 - output2_accuracy: 0.8612 - output2_loss: 0.6827 - val_loss: 1.6374 - val_output1_accuracy: 0.7473 - val_output1_loss: 0.8949 - val_output2_accuracy: 0.8306 - val_output2_loss: 0.7425
# Epoch 58/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5254 - output1_accuracy: 0.7796 - output1_loss: 0.8375 - output2_accuracy: 0.8583 - output2_loss: 0.6878 - val_loss: 1.6142 - val_output1_accuracy: 0.7437 - val_output1_loss: 0.8874 - val_output2_accuracy: 0.8352 - val_output2_loss: 0.7268
# Epoch 59/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5246 - output1_accuracy: 0.7792 - output1_loss: 0.8394 - output2_accuracy: 0.8585 - output2_loss: 0.6851 - val_loss: 1.6368 - val_output1_accuracy: 0.7380 - val_output1_loss: 0.9013 - val_output2_accuracy: 0.8305 - val_output2_loss: 0.7355
# Epoch 60/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5050 - output1_accuracy: 0.7865 - output1_loss: 0.8234 - output2_accuracy: 0.8658 - output2_loss: 0.6816 - val_loss: 1.6268 - val_output1_accuracy: 0.7337 - val_output1_loss: 0.9019 - val_output2_accuracy: 0.8402 - val_output2_loss: 0.7250
# Epoch 61/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5053 - output1_accuracy: 0.7902 - output1_loss: 0.8205 - output2_accuracy: 0.8600 - output2_loss: 0.6848 - val_loss: 1.6220 - val_output1_accuracy: 0.7503 - val_output1_loss: 0.8853 - val_output2_accuracy: 0.8288 - val_output2_loss: 0.7367
# Epoch 62/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5027 - output1_accuracy: 0.7910 - output1_loss: 0.8228 - output2_accuracy: 0.8642 - output2_loss: 0.6799 - val_loss: 1.6366 - val_output1_accuracy: 0.7458 - val_output1_loss: 0.8899 - val_output2_accuracy: 0.8253 - val_output2_loss: 0.7467
# Epoch 63/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4993 - output1_accuracy: 0.7903 - output1_loss: 0.8197 - output2_accuracy: 0.8638 - output2_loss: 0.6795 - val_loss: 1.6313 - val_output1_accuracy: 0.7384 - val_output1_loss: 0.9008 - val_output2_accuracy: 0.8345 - val_output2_loss: 0.7305
# Epoch 64/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5095 - output1_accuracy: 0.7852 - output1_loss: 0.8269 - output2_accuracy: 0.8642 - output2_loss: 0.6826 - val_loss: 1.6258 - val_output1_accuracy: 0.7472 - val_output1_loss: 0.8965 - val_output2_accuracy: 0.8322 - val_output2_loss: 0.7294
# Epoch 65/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4941 - output1_accuracy: 0.7882 - output1_loss: 0.8200 - output2_accuracy: 0.8680 - output2_loss: 0.6741 - val_loss: 1.6318 - val_output1_accuracy: 0.7359 - val_output1_loss: 0.9028 - val_output2_accuracy: 0.8297 - val_output2_loss: 0.7290
# Epoch 66/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4926 - output1_accuracy: 0.7916 - output1_loss: 0.8154 - output2_accuracy: 0.8689 - output2_loss: 0.6772 - val_loss: 1.5962 - val_output1_accuracy: 0.7552 - val_output1_loss: 0.8819 - val_output2_accuracy: 0.8458 - val_output2_loss: 0.7143
# Epoch 67/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.5007 - output1_accuracy: 0.7891 - output1_loss: 0.8222 - output2_accuracy: 0.8664 - output2_loss: 0.6785 - val_loss: 1.5995 - val_output1_accuracy: 0.7552 - val_output1_loss: 0.8815 - val_output2_accuracy: 0.8433 - val_output2_loss: 0.7180
# Epoch 68/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4910 - output1_accuracy: 0.7919 - output1_loss: 0.8166 - output2_accuracy: 0.8674 - output2_loss: 0.6744 - val_loss: 1.6210 - val_output1_accuracy: 0.7481 - val_output1_loss: 0.8916 - val_output2_accuracy: 0.8322 - val_output2_loss: 0.7294
# Epoch 69/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4812 - output1_accuracy: 0.7978 - output1_loss: 0.8091 - output2_accuracy: 0.8705 - output2_loss: 0.6721 - val_loss: 1.6174 - val_output1_accuracy: 0.7494 - val_output1_loss: 0.8925 - val_output2_accuracy: 0.8394 - val_output2_loss: 0.7249
# Epoch 70/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4957 - output1_accuracy: 0.7930 - output1_loss: 0.8166 - output2_accuracy: 0.8639 - output2_loss: 0.6792 - val_loss: 1.6155 - val_output1_accuracy: 0.7473 - val_output1_loss: 0.8911 - val_output2_accuracy: 0.8383 - val_output2_loss: 0.7244
# Epoch 71/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4825 - output1_accuracy: 0.7903 - output1_loss: 0.8187 - output2_accuracy: 0.8707 - output2_loss: 0.6638 - val_loss: 1.5989 - val_output1_accuracy: 0.7520 - val_output1_loss: 0.8813 - val_output2_accuracy: 0.8409 - val_output2_loss: 0.7176
# Epoch 72/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4746 - output1_accuracy: 0.7973 - output1_loss: 0.8062 - output2_accuracy: 0.8706 - output2_loss: 0.6684 - val_loss: 1.6036 - val_output1_accuracy: 0.7566 - val_output1_loss: 0.8768 - val_output2_accuracy: 0.8361 - val_output2_loss: 0.7268
# Epoch 73/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4806 - output1_accuracy: 0.7943 - output1_loss: 0.8094 - output2_accuracy: 0.8719 - output2_loss: 0.6712 - val_loss: 1.6249 - val_output1_accuracy: 0.7480 - val_output1_loss: 0.9009 - val_output2_accuracy: 0.8397 - val_output2_loss: 0.7240
# Epoch 74/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4718 - output1_accuracy: 0.7979 - output1_loss: 0.8059 - output2_accuracy: 0.8687 - output2_loss: 0.6659 - val_loss: 1.6157 - val_output1_accuracy: 0.7494 - val_output1_loss: 0.8898 - val_output2_accuracy: 0.8339 - val_output2_loss: 0.7259
# Epoch 75/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4798 - output1_accuracy: 0.7985 - output1_loss: 0.8050 - output2_accuracy: 0.8633 - output2_loss: 0.6748 - val_loss: 1.5922 - val_output1_accuracy: 0.7516 - val_output1_loss: 0.8793 - val_output2_accuracy: 0.8431 - val_output2_loss: 0.7129
# Epoch 76/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4735 - output1_accuracy: 0.8020 - output1_loss: 0.8031 - output2_accuracy: 0.8692 - output2_loss: 0.6704 - val_loss: 1.6039 - val_output1_accuracy: 0.7536 - val_output1_loss: 0.8818 - val_output2_accuracy: 0.8388 - val_output2_loss: 0.7220
# Epoch 77/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4683 - output1_accuracy: 0.7973 - output1_loss: 0.8030 - output2_accuracy: 0.8717 - output2_loss: 0.6654 - val_loss: 1.6039 - val_output1_accuracy: 0.7511 - val_output1_loss: 0.8861 - val_output2_accuracy: 0.8388 - val_output2_loss: 0.7179
# Epoch 78/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4761 - output1_accuracy: 0.7941 - output1_loss: 0.8083 - output2_accuracy: 0.8686 - output2_loss: 0.6678 - val_loss: 1.6024 - val_output1_accuracy: 0.7541 - val_output1_loss: 0.8739 - val_output2_accuracy: 0.8334 - val_output2_loss: 0.7285
# Epoch 79/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4772 - output1_accuracy: 0.7985 - output1_loss: 0.8039 - output2_accuracy: 0.8671 - output2_loss: 0.6732 - val_loss: 1.5801 - val_output1_accuracy: 0.7655 - val_output1_loss: 0.8614 - val_output2_accuracy: 0.8425 - val_output2_loss: 0.7187
# Epoch 80/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4642 - output1_accuracy: 0.8049 - output1_loss: 0.7979 - output2_accuracy: 0.8720 - output2_loss: 0.6664 - val_loss: 1.6244 - val_output1_accuracy: 0.7531 - val_output1_loss: 0.8967 - val_output2_accuracy: 0.8331 - val_output2_loss: 0.7277
# Epoch 81/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4652 - output1_accuracy: 0.7995 - output1_loss: 0.8008 - output2_accuracy: 0.8723 - output2_loss: 0.6644 - val_loss: 1.5803 - val_output1_accuracy: 0.7548 - val_output1_loss: 0.8744 - val_output2_accuracy: 0.8466 - val_output2_loss: 0.7059
# Epoch 82/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4714 - output1_accuracy: 0.7968 - output1_loss: 0.8013 - output2_accuracy: 0.8696 - output2_loss: 0.6701 - val_loss: 1.6125 - val_output1_accuracy: 0.7419 - val_output1_loss: 0.8912 - val_output2_accuracy: 0.8419 - val_output2_loss: 0.7213
# Epoch 83/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4649 - output1_accuracy: 0.8043 - output1_loss: 0.8024 - output2_accuracy: 0.8727 - output2_loss: 0.6625 - val_loss: 1.5906 - val_output1_accuracy: 0.7527 - val_output1_loss: 0.8736 - val_output2_accuracy: 0.8430 - val_output2_loss: 0.7170
# Epoch 84/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4646 - output1_accuracy: 0.7978 - output1_loss: 0.8046 - output2_accuracy: 0.8757 - output2_loss: 0.6600 - val_loss: 1.6141 - val_output1_accuracy: 0.7513 - val_output1_loss: 0.8859 - val_output2_accuracy: 0.8350 - val_output2_loss: 0.7282
# Epoch 85/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4554 - output1_accuracy: 0.8000 - output1_loss: 0.7976 - output2_accuracy: 0.8747 - output2_loss: 0.6578 - val_loss: 1.5871 - val_output1_accuracy: 0.7633 - val_output1_loss: 0.8632 - val_output2_accuracy: 0.8336 - val_output2_loss: 0.7239
# Epoch 86/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4556 - output1_accuracy: 0.8080 - output1_loss: 0.7883 - output2_accuracy: 0.8719 - output2_loss: 0.6673 - val_loss: 1.6047 - val_output1_accuracy: 0.7569 - val_output1_loss: 0.8785 - val_output2_accuracy: 0.8367 - val_output2_loss: 0.7262
# Epoch 87/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4598 - output1_accuracy: 0.8011 - output1_loss: 0.7986 - output2_accuracy: 0.8727 - output2_loss: 0.6613 - val_loss: 1.5926 - val_output1_accuracy: 0.7556 - val_output1_loss: 0.8757 - val_output2_accuracy: 0.8398 - val_output2_loss: 0.7169
# Epoch 88/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4593 - output1_accuracy: 0.8039 - output1_loss: 0.7936 - output2_accuracy: 0.8737 - output2_loss: 0.6657 - val_loss: 1.5648 - val_output1_accuracy: 0.7617 - val_output1_loss: 0.8625 - val_output2_accuracy: 0.8484 - val_output2_loss: 0.7024
# Epoch 89/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4617 - output1_accuracy: 0.8000 - output1_loss: 0.7965 - output2_accuracy: 0.8729 - output2_loss: 0.6652 - val_loss: 1.6028 - val_output1_accuracy: 0.7481 - val_output1_loss: 0.8875 - val_output2_accuracy: 0.8428 - val_output2_loss: 0.7153
# Epoch 90/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4524 - output1_accuracy: 0.8039 - output1_loss: 0.7923 - output2_accuracy: 0.8731 - output2_loss: 0.6601 - val_loss: 1.5973 - val_output1_accuracy: 0.7487 - val_output1_loss: 0.8803 - val_output2_accuracy: 0.8402 - val_output2_loss: 0.7170
# Epoch 91/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4661 - output1_accuracy: 0.8032 - output1_loss: 0.7985 - output2_accuracy: 0.8700 - output2_loss: 0.6677 - val_loss: 1.5979 - val_output1_accuracy: 0.7558 - val_output1_loss: 0.8816 - val_output2_accuracy: 0.8438 - val_output2_loss: 0.7163
# Epoch 92/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - loss: 1.4577 - output1_accuracy: 0.8074 - output1_loss: 0.7919 - output2_accuracy: 0.8722 - output2_loss: 0.6658 - val_loss: 1.5804 - val_output1_accuracy: 0.7553 - val_output1_loss: 0.8729 - val_output2_accuracy: 0.8462 - val_output2_loss: 0.7075
# Epoch 93/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4603 - output1_accuracy: 0.8040 - output1_loss: 0.7971 - output2_accuracy: 0.8728 - output2_loss: 0.6632 - val_loss: 1.5877 - val_output1_accuracy: 0.7500 - val_output1_loss: 0.8770 - val_output2_accuracy: 0.8444 - val_output2_loss: 0.7106
# Epoch 94/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4539 - output1_accuracy: 0.8032 - output1_loss: 0.7945 - output2_accuracy: 0.8772 - output2_loss: 0.6594 - val_loss: 1.6028 - val_output1_accuracy: 0.7509 - val_output1_loss: 0.8815 - val_output2_accuracy: 0.8370 - val_output2_loss: 0.7213
# Epoch 95/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4464 - output1_accuracy: 0.8079 - output1_loss: 0.7877 - output2_accuracy: 0.8750 - output2_loss: 0.6587 - val_loss: 1.5887 - val_output1_accuracy: 0.7555 - val_output1_loss: 0.8730 - val_output2_accuracy: 0.8442 - val_output2_loss: 0.7157
# Epoch 96/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4485 - output1_accuracy: 0.8052 - output1_loss: 0.7907 - output2_accuracy: 0.8762 - output2_loss: 0.6577 - val_loss: 1.5834 - val_output1_accuracy: 0.7522 - val_output1_loss: 0.8810 - val_output2_accuracy: 0.8514 - val_output2_loss: 0.7025
# Epoch 97/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4510 - output1_accuracy: 0.8064 - output1_loss: 0.7870 - output2_accuracy: 0.8717 - output2_loss: 0.6640 - val_loss: 1.5891 - val_output1_accuracy: 0.7538 - val_output1_loss: 0.8762 - val_output2_accuracy: 0.8441 - val_output2_loss: 0.7129
# Epoch 98/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4492 - output1_accuracy: 0.8026 - output1_loss: 0.7931 - output2_accuracy: 0.8771 - output2_loss: 0.6561 - val_loss: 1.5925 - val_output1_accuracy: 0.7589 - val_output1_loss: 0.8709 - val_output2_accuracy: 0.8388 - val_output2_loss: 0.7216
# Epoch 99/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4437 - output1_accuracy: 0.8061 - output1_loss: 0.7866 - output2_accuracy: 0.8756 - output2_loss: 0.6571 - val_loss: 1.5897 - val_output1_accuracy: 0.7605 - val_output1_loss: 0.8700 - val_output2_accuracy: 0.8408 - val_output2_loss: 0.7196
# Epoch 100/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4487 - output1_accuracy: 0.8054 - output1_loss: 0.7902 - output2_accuracy: 0.8751 - output2_loss: 0.6585 - val_loss: 1.5781 - val_output1_accuracy: 0.7580 - val_output1_loss: 0.8654 - val_output2_accuracy: 0.8397 - val_output2_loss: 0.7127
# Epoch 101/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4502 - output1_accuracy: 0.8090 - output1_loss: 0.7896 - output2_accuracy: 0.8724 - output2_loss: 0.6606 - val_loss: 1.6016 - val_output1_accuracy: 0.7570 - val_output1_loss: 0.8740 - val_output2_accuracy: 0.8323 - val_output2_loss: 0.7276
# Epoch 102/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4487 - output1_accuracy: 0.8104 - output1_loss: 0.7852 - output2_accuracy: 0.8746 - output2_loss: 0.6634 - val_loss: 1.5994 - val_output1_accuracy: 0.7538 - val_output1_loss: 0.8740 - val_output2_accuracy: 0.8417 - val_output2_loss: 0.7253
# Epoch 103/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4526 - output1_accuracy: 0.8010 - output1_loss: 0.7958 - output2_accuracy: 0.8753 - output2_loss: 0.6568 - val_loss: 1.5709 - val_output1_accuracy: 0.7511 - val_output1_loss: 0.8736 - val_output2_accuracy: 0.8487 - val_output2_loss: 0.6973
# Epoch 104/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4438 - output1_accuracy: 0.8038 - output1_loss: 0.7957 - output2_accuracy: 0.8819 - output2_loss: 0.6480 - val_loss: 1.5719 - val_output1_accuracy: 0.7594 - val_output1_loss: 0.8587 - val_output2_accuracy: 0.8378 - val_output2_loss: 0.7132
# Epoch 105/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4480 - output1_accuracy: 0.8091 - output1_loss: 0.7879 - output2_accuracy: 0.8728 - output2_loss: 0.6602 - val_loss: 1.5845 - val_output1_accuracy: 0.7486 - val_output1_loss: 0.8814 - val_output2_accuracy: 0.8478 - val_output2_loss: 0.7031
# Epoch 106/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4584 - output1_accuracy: 0.7969 - output1_loss: 0.8001 - output2_accuracy: 0.8761 - output2_loss: 0.6583 - val_loss: 1.5865 - val_output1_accuracy: 0.7570 - val_output1_loss: 0.8717 - val_output2_accuracy: 0.8409 - val_output2_loss: 0.7148
# Epoch 107/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4476 - output1_accuracy: 0.8045 - output1_loss: 0.7917 - output2_accuracy: 0.8782 - output2_loss: 0.6559 - val_loss: 1.5679 - val_output1_accuracy: 0.7603 - val_output1_loss: 0.8679 - val_output2_accuracy: 0.8514 - val_output2_loss: 0.7000
# Epoch 108/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4603 - output1_accuracy: 0.8004 - output1_loss: 0.8016 - output2_accuracy: 0.8761 - output2_loss: 0.6587 - val_loss: 1.6013 - val_output1_accuracy: 0.7572 - val_output1_loss: 0.8742 - val_output2_accuracy: 0.8372 - val_output2_loss: 0.7271
# Epoch 109/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4508 - output1_accuracy: 0.8057 - output1_loss: 0.7955 - output2_accuracy: 0.8766 - output2_loss: 0.6553 - val_loss: 1.5702 - val_output1_accuracy: 0.7580 - val_output1_loss: 0.8682 - val_output2_accuracy: 0.8511 - val_output2_loss: 0.7020
# Epoch 110/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4478 - output1_accuracy: 0.8046 - output1_loss: 0.7929 - output2_accuracy: 0.8769 - output2_loss: 0.6549 - val_loss: 1.5811 - val_output1_accuracy: 0.7609 - val_output1_loss: 0.8736 - val_output2_accuracy: 0.8472 - val_output2_loss: 0.7075
# Epoch 111/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4474 - output1_accuracy: 0.8040 - output1_loss: 0.7950 - output2_accuracy: 0.8801 - output2_loss: 0.6524 - val_loss: 1.5929 - val_output1_accuracy: 0.7567 - val_output1_loss: 0.8783 - val_output2_accuracy: 0.8438 - val_output2_loss: 0.7146
# Epoch 112/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4553 - output1_accuracy: 0.8011 - output1_loss: 0.7971 - output2_accuracy: 0.8793 - output2_loss: 0.6582 - val_loss: 1.5775 - val_output1_accuracy: 0.7653 - val_output1_loss: 0.8581 - val_output2_accuracy: 0.8356 - val_output2_loss: 0.7194
# Epoch 113/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4429 - output1_accuracy: 0.8084 - output1_loss: 0.7886 - output2_accuracy: 0.8775 - output2_loss: 0.6543 - val_loss: 1.5652 - val_output1_accuracy: 0.7631 - val_output1_loss: 0.8547 - val_output2_accuracy: 0.8469 - val_output2_loss: 0.7106
# Epoch 114/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4447 - output1_accuracy: 0.8093 - output1_loss: 0.7871 - output2_accuracy: 0.8767 - output2_loss: 0.6577 - val_loss: 1.5827 - val_output1_accuracy: 0.7583 - val_output1_loss: 0.8685 - val_output2_accuracy: 0.8434 - val_output2_loss: 0.7143
# Epoch 115/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4460 - output1_accuracy: 0.8103 - output1_loss: 0.7824 - output2_accuracy: 0.8725 - output2_loss: 0.6637 - val_loss: 1.5668 - val_output1_accuracy: 0.7652 - val_output1_loss: 0.8594 - val_output2_accuracy: 0.8442 - val_output2_loss: 0.7074
# Epoch 116/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4513 - output1_accuracy: 0.8025 - output1_loss: 0.7930 - output2_accuracy: 0.8759 - output2_loss: 0.6583 - val_loss: 1.5910 - val_output1_accuracy: 0.7598 - val_output1_loss: 0.8759 - val_output2_accuracy: 0.8416 - val_output2_loss: 0.7152
# Epoch 117/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4519 - output1_accuracy: 0.8031 - output1_loss: 0.7931 - output2_accuracy: 0.8769 - output2_loss: 0.6588 - val_loss: 1.5746 - val_output1_accuracy: 0.7703 - val_output1_loss: 0.8548 - val_output2_accuracy: 0.8353 - val_output2_loss: 0.7197
# Epoch 118/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4454 - output1_accuracy: 0.8063 - output1_loss: 0.7903 - output2_accuracy: 0.8789 - output2_loss: 0.6551 - val_loss: 1.5763 - val_output1_accuracy: 0.7545 - val_output1_loss: 0.8683 - val_output2_accuracy: 0.8487 - val_output2_loss: 0.7080
# Epoch 119/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4423 - output1_accuracy: 0.8073 - output1_loss: 0.7830 - output2_accuracy: 0.8745 - output2_loss: 0.6593 - val_loss: 1.5624 - val_output1_accuracy: 0.7675 - val_output1_loss: 0.8631 - val_output2_accuracy: 0.8550 - val_output2_loss: 0.6992
# Epoch 120/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - loss: 1.4389 - output1_accuracy: 0.8081 - output1_loss: 0.7867 - output2_accuracy: 0.8791 - output2_loss: 0.6522 - val_loss: 1.5863 - val_output1_accuracy: 0.7522 - val_output1_loss: 0.8810 - val_output2_accuracy: 0.8469 - val_output2_loss: 0.7054

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 32, 32, 3)      │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 32, 32, 64)     │          1,792 │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 32, 32, 64)     │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ silu (Silu)               │ (None, 32, 32, 64)     │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 32, 32, 64)     │              0 │ silu[0][0]             │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 32, 32, 128)    │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 32, 32, 128)    │            512 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ silu_1 (Silu)             │ (None, 32, 32, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 32, 32, 128)    │              0 │ silu_1[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 32, 32, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 32, 32, 256)    │          1,024 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ silu_2 (Silu)             │ (None, 32, 32, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ silu_2[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 32, 32, 512)    │          2,048 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ silu_3 (Silu)             │ (None, 32, 32, 512)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 32, 32, 512)    │              0 │ silu_3[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 32, 32, 1024)   │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 32, 32, 1024)   │          4,096 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ silu_4 (Silu)             │ (None, 32, 32, 1024)   │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 32, 32, 1024)   │              0 │ silu_4[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1024)           │              0 │ max_pooling2d_4[0][0]  │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1024)           │      1,049,600 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 1024)           │      1,049,600 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu (LeakyReLU)   │ (None, 1024)           │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU) │ (None, 1024)           │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 1024)           │              0 │ leaky_re_lu[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 1024)           │              0 │ leaky_re_lu_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output1 (Dense)           │ (None, 5)              │          5,125 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output2 (Dense)           │ (None, 5)              │          5,125 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 25,155,999 (95.96 MB)
#  Trainable params: 8,384,010 (31.98 MB)
#  Non-trainable params: 3,968 (15.50 KB)
#  Optimizer params: 16,768,021 (63.96 MB)

# %%
# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot training and validation accuracy for each output
plt.figure(figsize=(10, 5))
plt.plot(history.history['output1_accuracy'], label='Train Accuracy (Output 1)')
plt.plot(history.history['val_output1_accuracy'], label='Validation Accuracy (Output 1)')
plt.plot(history.history['output2_accuracy'], label='Train Accuracy (Output 2)', linestyle='dashed')
plt.plot(history.history['val_output2_accuracy'], label='Validation Accuracy (Output 2)', linestyle='dashed')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Save the model weights
model.save_weights("enhanced_cnn_best_model.weights.h5")

# %%
def eval_model(model):
    testgen = datagenerator(cifar10_x_test_1, cifar10_x_test_2, cifar10_y_test_1, cifar10_y_test_2, 10000)
    eval_samples_x, eval_samples_y = next(testgen)
    predictions = model.predict(eval_samples_x)
    pred1 = np.argmax(predictions[0], axis=1)
    pred2 = np.argmax(predictions[1], axis=1)
    correct_guesses_1 = pred1 == np.argmax(eval_samples_y[0], axis=1)
    correct_guesses_2 = pred2 == np.argmax(eval_samples_y[1], axis=1)
    return (np.mean(correct_guesses_1) + np.mean(correct_guesses_2)) / 2

repeat_eval = 10
eval_results = []
for i in range(repeat_eval):
    eval_results.append(eval_model(model))

print("Mean accuracy =", np.mean(eval_results))
print("Standard deviation =", np.std(eval_results))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Mean accuracy = 0.7966399999999999
# Standard deviation = 0.0032478300448145715

# %% [markdown]
# ### **`Additional exploration and work:`** For fine-tuning the model Transfer learning can be applied

# %% [markdown]
# # What to Submit
#
# As usual, you need to submit a single notebook that must be executable on Colab. The notebook should be properly commented and include a complete record of the training process, as well as the calculation of accuracy according to the guidelines provided above.
#
# # Good luck!
